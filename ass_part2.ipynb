# %% [markdown]
# <a href="https://colab.research.google.com/github/Harshithsadula/AIML_Batch15/blob/main/ass_part2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
people = ['Ann','Brandon','Chen', 'David', 'Emily', 'Farook','Gagan', 'Hamish', 'Imran', 'Julio',' Katherine', 'Lily']
age = [21,12,32,45,37,18,28,52,5,40,48,15]
weight = [55,35,77,68,70,60,72,69,18,65,82,48]
height = [160,135,170,165,173,168, 175, 159,105,171,155,158]

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(12,4))
plt.title("People's weight in kgs", fontsize=16, fontstyle='italic')
# Out:
# Text(0.5, 1.0, "People's weight in kgs")

# %%
plt.bar(people, height=weight, width=0.6, color='orange', edgecolor='k', alpha=0.6)
plt.xlabel("People", fontsize=15)
plt.xticks(fontsize=14, rotation=30)
plt.yticks(fontsize=14)
plt.ylabel("Weight (in kgs)", fontsize=15)
plt.show()

# %%
plt.scatter(weight, height)
plt.title("Relationship between Weight and Height of Patients")
plt.ylabel("Height in Meters")
plt.xlabel("Weight of Patients in Kgs")
plt.show()

# %%
plt.plot(age, height)
plt.title('Simple Line Plot')
plt.xlabel('X-axis Label')
plt.ylabel('Y-axis Label')
plt.show()

# %%
import numpy as np
plt.figure(figsize=(7,5))

# %%
plt.hist(weight,color='green',edgecolor='k',alpha=0.5,bins=10)
plt.xlabel("WEIGHT in kgs", fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.show()
